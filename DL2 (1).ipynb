# %%
#importing necessary libraries
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
# %matplotlib inline

# %%
mnist=tf.keras.datasets.mnist
(x_train,y_train),(x_test,y_test)= mnist.load_data()

# %%
plt.matshow(x_train[97])

# %%
plt.imshow(x_train[56],cmap="gray")

# %%
x_train=x_train / 255
_test = x_test / 255
# to bring the array in a specific range
print(x_train.min())
print(x_train.max())
# Out:
# 0.0
# 1.0

# %%
model  = keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(128,activation="relu"),
    keras.layers.Dense(10,activation="softmax")
])
model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_10 (Flatten)        (None, 784)               0
#
#  dense_20 (Dense)            (None, 128)               100480
#
#  dense_21 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer="sgd",
loss="sparse_categorical_crossentropy",
metrics=['accuracy'])

# %%
history=model.fit(x_train,
                  y_train,validation_data=(x_test,y_test),epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 1s 659us/step - loss: 0.6411 - accuracy: 0.8437 - val_loss: 36.1227 - val_accuracy: 0.9039
# Epoch 2/10
# 1875/1875 [==============================] - 1s 594us/step - loss: 0.3317 - accuracy: 0.9089 - val_loss: 34.9804 - val_accuracy: 0.9174
# Epoch 3/10
# 1875/1875 [==============================] - 1s 591us/step - loss: 0.2835 - accuracy: 0.9207 - val_loss: 32.8953 - val_accuracy: 0.9260
# Epoch 4/10
# 1875/1875 [==============================] - 1s 596us/step - loss: 0.2531 - accuracy: 0.9296 - val_loss: 31.8133 - val_accuracy: 0.9304
# Epoch 5/10
# 1875/1875 [==============================] - 1s 610us/step - loss: 0.2307 - accuracy: 0.9357 - val_loss: 28.3138 - val_accuracy: 0.9381
# Epoch 6/10
# 1875/1875 [==============================] - 1s 592us/step - loss: 0.2125 - accuracy: 0.9408 - val_loss: 27.4664 - val_accuracy: 0.9402
# Epoch 7/10
# 1875/1875 [==============================] - 1s 600us/step - loss: 0.1974 - accuracy: 0.9448 - val_loss: 25.4194 - val_accuracy: 0.9432
# Epoch 8/10
# 1875/1875 [==============================] - 1s 596us/step - loss: 0.1843 - accuracy: 0.9488 - val_loss: 24.6228 - val_accuracy: 0.9461
# Epoch 9/10
# 1875/1875 [==============================] - 1s 582us/step - loss: 0.1732 - accuracy: 0.9517 - val_loss: 22.4929 - val_accuracy: 0.9499
# Epoch 10/10
# 1875/1875 [==============================] - 1s 587us/step - loss: 0.1635 - accuracy: 0.9542 - val_loss: 21.6254 - val_accuracy: 0.9512

# %%
test_loss,test_acc=model.evaluate(x_test,y_test)
print("Loss=%.3f" %test_loss)
print("Accuracy=%.3f" %test_acc)
# Out:
# 313/313 [==============================] - 0s 392us/step - loss: 21.6254 - accuracy: 0.9512
# Loss=21.625
# Accuracy=0.951

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f"Loss: {test_loss:.3f}, Accuracy: {test_acc:.3f}")
# Out:
# 313/313 [==============================] - 0s 606us/step - loss: 21.6254 - accuracy: 0.9512
# Loss: 21.625, Accuracy: 0.951

# %%
n=random.randint(0,9999)
plt.imshow(x_test[n])
plt.show()

# %%
predicted_value=model.predict(x_test)
plt.imshow(x_test[n])
# Out:
# 313/313 [==============================] - 0s 333us/step

# %%
history.history.keys()

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train','Validation'],loc='upper left')

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train','Validation'],loc='upper left')
